# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores.chroma import Chroma

# %%
text_splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=400,
    chunk_overlap=100
)

# %%
loader = TextLoader("Corpus.txt")
docs = loader.load_and_split(
    text_splitter=text_splitter
)
# Out:
# Created a chunk of size 415, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 415, which is longer than the specified 400
# Created a chunk of size 410, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 406, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 411, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 410, which is longer than the specified 400
# ...

# %% [markdown]
# embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
import joblib as jb

# %% [markdown]
# jb.dump(embeddings, "embeddings")

# %%
embeddings = jb.load("embeddings")

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
db = Chroma.from_documents(
    docs,
    embedding=embeddings,
    persist_directory="data_weather2"
)

# %%
from langchain.llms import LlamaCpp
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores.chroma import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough

# %%
llm = LlamaCpp(
    model_path=r"C:\Users\sulek\Documents\PythonScripts\zephyr-7b-beta.Q4_0.gguf",
    temperature=0.75,
    max_tokens=2000,
    top_p=1,
    verbose=True,
)
# Out:
# llama_model_loader: loaded meta data with 21 key-value pairs and 291 tensors from C:\Users\sulek\Documents\PythonScripts\zephyr-7b-beta.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = huggingfaceh4_zephyr-7b-beta
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# ...

# %% [markdown]
# embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
vectorstore = Chroma(
    persist_directory="data_weather2",
    embedding_function=embeddings
)

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 1})

# %%
template = """Answer the question based only on the following context
 
{context}
 
Question:{question}
Answer:
"""

# %%
prompt = ChatPromptTemplate.from_template(template)

# %%
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
)

# %%
for chunk in chain.stream("What is the weather in February?"):
    print(chunk, end="", flush=True)
# Out:
# The weather in February, as described by the given context, is characterized by a minimum temperature of 18 degrees Celsius, a maximum temperature of 31 degrees Celsius, southeast wind with a velocity of 17.59910353 meters per second, humidity of 86%, atmospheric pressure of 780, cloud cover in the form of cirrostratus, rainfall of 21 millimeters, UV radiation level of 0.204036091, and an intensity of light of 13977 lux. It can be interpreted as generally warm with some cloud cover, humidity, and rainfall, but also with moderate UV radiation levels for the time of year.
# llama_print_timings:        load time =    1149.58 ms
# llama_print_timings:      sample time =      29.58 ms /   164 runs   (    0.18 ms per token,  5543.91 tokens per second)
# llama_print_timings: prompt eval time =   21431.95 ms /   198 tokens (  108.24 ms per token,     9.24 tokens per second)
# ...

# %%
for chunk in chain.stream("What is the weather in June?"):
    print(chunk, end="", flush=True)
# Out:
# Llama.generate: prefix-match hit
# The weather on the specific day of June 28th, 2022, as described in the given context, includes a minimum temperature of 17 degrees Celsius, a maximum temperature of 36 degrees Celsius, southwest wind direction at a velocity of 47.98 m/s, an atmospheric pressure of 921 hPa, a humidity level of 89%, a carbon monoxide level of 0.499 ppm, UV rays intensity of 0.666 W/m², light intensity of 21043 lux, cumulus clouds, and rainfall amounting to 21 mm.
# llama_print_timings:        load time =    1149.58 ms
# llama_print_timings:      sample time =      25.12 ms /   151 runs   (    0.17 ms per token,  6010.67 tokens per second)
# llama_print_timings: prompt eval time =   15335.19 ms /   171 tokens (   89.68 ms per token,    11.15 tokens per second)
# llama_print_timings:        eval time =   25882.58 ms /   150 runs   (  172.55 ms per token,     5.80 tokens per second)
# llama_print_timings:       total time =   41717.48 ms /   321 tokens
